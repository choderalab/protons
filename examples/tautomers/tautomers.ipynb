# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from protons.app import logger
from protons.app.logger import log
from protons import app
from simtk import openmm as mm
import logging
log.setLevel(logging.DEBUG)
import yaml
import tautomer_utils
from protons.app.driver import SAMSApproach, Stage, UpdateRule
# Out:
# <style>.container { width:100% !important; }</style>
# [__init__.py:415 -              wrapper() ] CACHEDIR=/home/mwieder/.cache/matplotlib
# [font_manager.py:1362 -             <module>() ] Using fontManager instance from /home/mwieder/.cache/matplotlib/fontlist-v300.json
# [pyplot.py:211 -       switch_backend() ] Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# [pyplot.py:211 -       switch_backend() ] Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
settings = yaml.load(open('keto-enol.json', "r"))
settings['pH'] = 7.8
settings['resname'] = 'UNL'
# Out:
# /home/mwieder/anaconda3/envs/protons-dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """Entry point for launching an IPython kernel.

# %%
t1 =  { 'log_population' : '1.0', 'net_charge' : 0 }
t2 =  { 'log_population' : '1.0', 'net_charge' : 0 }
isomer_dictionary = [ t1, t2 ]
tautomer_utils.setting_up_tautomer(settings, isomer_dictionary)
# Out:
# [ligands.py:1598 - generate_protons_ffxml() ] Processing Epik output...
# [ligands.py:1601 - generate_protons_ffxml() ] Parametrizing the isomers...
# [ligands.py:1613 - generate_protons_ffxml() ] ffxml generation for 0
# [openeye.py:496 -     molecule_to_mol2() ] ISOMER-0
# [ligands.py:1617 - generate_protons_ffxml() ] <ForceField>
#  <Info>
#   <DateGenerated>2019-04-03</DateGenerated>
#  </Info>
#  <Residues>
#   <Residue name="ISO">
#    <Atom name="O1" type="o" charge="-0.5453"/>
#    <Atom name="C2" type="c" charge="0.5819"/>
#    <Atom name="C3" type="ca" charge="-0.1679"/>
#    <Atom name="C4" type="ca" charge="-0.07"/>
#    <Atom name="C5" type="ca" charge="-0.145"/>
#    <Atom name="C6" type="ca" charge="-0.1004"/>
#    <Atom name="C7" type="ca" charge="-0.1364"/>
#    <Atom name="C8" type="ca" charge="-0.0118"/>
#    <Atom name="C9" type="ce" charge="-0.1238"/>
#    <Atom name="C10" type="c2" charge="-0.1422"/>
#    <Atom name="C11" type="c3" charge="-0.1522"/>
#    <Atom name="H1" type="ha" charge="0.157"/>
#    <Atom name="H2" type="ha" charge="0.1379"/>
#    <Atom name="H3" type="ha" charge="0.1344"/>
#    <Atom name="H4" type="ha" charge="0.1362"/>
#    <Atom name="H5" type="ha" charge="0.1354"/>
#    <Atom name="H6" type="ha" charge="0.1316"/>
#    <Atom name="H7" type="hc" charge="0.0902"/>
#    <Atom name="H8" type="hc" charge="0.0902"/>
#    <Bond atomName1="O1" atomName2="C2"/>
#    <Bond atomName1="C2" atomName2="C3"/>
#    <Bond atomName1="C8" atomName2="C9"/>
#    <Bond atomName1="C9" atomName2="C10"/>
#    <Bond atomName1="C10" atomName2="C11"/>
#    <Bond atomName1="C2" atomName2="C11"/>
#    <Bond atomName1="C4" atomName2="H1"/>
#    <Bond atomName1="C5" atomName2="H2"/>
#    <Bond atomName1="C6" atomName2="H3"/>
#    <Bond atomName1="C7" atomName2="H4"/>
#    <Bond atomName1="C9" atomName2="H5"/>
#    <Bond atomName1="C10" atomName2="H6"/>
#    <Bond atomName1="C11" atomName2="H7"/>
#    <Bond atomName1="C11" atomName2="H8"/>
#    <Bond atomName1="C3" atomName2="C8"/>
#    <Bond atomName1="C6" atomName2="C7"/>
#    <Bond atomName1="C4" atomName2="C5"/>
#    <Bond atomName1="C7" atomName2="C8"/>
#    <Bond atomName1="C5" atomName2="C6"/>
#    <Bond atomName1="C3" atomName2="C4"/>
#   </Residue>
#  </Residues>
#  <PeriodicTorsionForce>
#   <Proper type1="ca" type2="ca" type3="ce" type4="c2" periodicity1="2" phase1="3.141592653589793" k1="2.9288"/>
#   <Proper type1="ca" type2="ca" type3="ce" type4="ha" periodicity1="2" phase1="3.141592653589793" k1="2.9288"/>
#   <Improper type1="c" type2="c3" type3="ca" type4="o" periodicity1="2" phase1="3.141592653589793" k1="43.932"/>
#   <Improper type1="ca" type2="c" type3="ca" type4="ca" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="ca" type2="ca" type3="ca" type4="ha" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="ca" type2="ca" type3="ca" type4="ce" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="ce" type2="c2" type3="ca" type4="ha" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="c2" type2="c3" type3="ce" type4="ha" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#  </PeriodicTorsionForce>
# </ForceField>
#
# [ligands.py:1752 - generate_tautomer_torsion_definitions() ] Generate tautomer torsion definitions ...
# [ligands.py:1613 - generate_protons_ffxml() ] ffxml generation for 1
# [openeye.py:496 -     molecule_to_mol2() ] ISOMER-1
# [ligands.py:1617 - generate_protons_ffxml() ] <ForceField>
#  <Info>
#   <DateGenerated>2019-04-03</DateGenerated>
#  </Info>
#  <Residues>
#   <Residue name="ISO">
#    <Atom name="O1" type="oh" charge="-0.5008"/>
#    <Atom name="C2" type="ca" charge="0.1463"/>
#    <Atom name="C3" type="ca" charge="-0.0496"/>
#    <Atom name="C4" type="ca" charge="-0.0922"/>
#    <Atom name="C5" type="ca" charge="-0.141"/>
#    <Atom name="C6" type="ca" charge="-0.1145"/>
#    <Atom name="C7" type="ca" charge="-0.1305"/>
#    <Atom name="C8" type="ca" charge="-0.0098"/>
#    <Atom name="C9" type="ca" charge="-0.1543"/>
#    <Atom name="C10" type="ca" charge="-0.0878"/>
#    <Atom name="C11" type="ca" charge="-0.2358"/>
#    <Atom name="H1" type="ha" charge="0.1476"/>
#    <Atom name="H2" type="ha" charge="0.1333"/>
#    <Atom name="H3" type="ha" charge="0.1322"/>
#    <Atom name="H4" type="ha" charge="0.1339"/>
#    <Atom name="H5" type="ha" charge="0.1348"/>
#    <Atom name="H6" type="ha" charge="0.1333"/>
#    <Atom name="H9" type="ho" charge="0.4238"/>
#    <Atom name="H7" type="ha" charge="0.1311"/>
#    <Bond atomName1="C2" atomName2="C3"/>
#    <Bond atomName1="C8" atomName2="C9"/>
#    <Bond atomName1="C9" atomName2="C10"/>
#    <Bond atomName1="C10" atomName2="C11"/>
#    <Bond atomName1="C4" atomName2="H1"/>
#    <Bond atomName1="C5" atomName2="H2"/>
#    <Bond atomName1="C6" atomName2="H3"/>
#    <Bond atomName1="C7" atomName2="H4"/>
#    <Bond atomName1="C9" atomName2="H5"/>
#    <Bond atomName1="C10" atomName2="H6"/>
#    <Bond atomName1="C3" atomName2="C8"/>
#    <Bond atomName1="C6" atomName2="C7"/>
#    <Bond atomName1="C4" atomName2="C5"/>
#    <Bond atomName1="C7" atomName2="C8"/>
#    <Bond atomName1="C5" atomName2="C6"/>
#    <Bond atomName1="C3" atomName2="C4"/>
#    <Bond atomName1="O1" atomName2="H9"/>
#    <Bond atomName1="O1" atomName2="C2"/>
#    <Bond atomName1="C2" atomName2="C11"/>
#    <Bond atomName1="C11" atomName2="H7"/>
#   </Residue>
#  </Residues>
#  <PeriodicTorsionForce>
#   <Improper type1="ca" type2="ca" type3="ca" type4="oh" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="ca" type2="ca" type3="ca" type4="ca" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#   <Improper type1="ca" type2="ca" type3="ca" type4="ha" periodicity1="2" phase1="3.141592653589793" k1="4.6024"/>
#  </PeriodicTorsionForce>
# </ForceField>
#
# [ligands.py:1752 - generate_tautomer_torsion_definitions() ] Generate tautomer torsion definitions ...
# /home/mwieder/anaconda3/envs/protons-dev/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# [_base.py:2515 - _update_title_position() ] update_title_pos
# [font_manager.py:1254 -     _findfont_cached() ] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=bold:stretch=normal:size=12.0 to DejaVu Sans ('/home/mwieder/anaconda3/envs/protons-dev/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf') with score of 0.000000.
# [font_manager.py:1254 -     _findfont_cached() ] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/home/mwieder/anaconda3/envs/protons-dev/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# [_base.py:2515 - _update_title_position() ] update_title_pos
# [_base.py:2515 - _update_title_position() ] update_title_pos
# [_base.py:2515 - _update_title_position() ] update_title_pos
# [ligands.py:2211 -         _add_isomers() ] Add tautomer information ...
# [ligands.py:2258 -         _add_isomers() ] ISOMER: 0
# [ligands.py:2260 -         _add_isomers() ] <State index="0" log_population="1.0" g_k="0.0" proton_count="0">
#                 <Condition pH="7.8" log_population="1.0" temperature_kelvin="298.15"/>
#                 </State>
# [ligands.py:2287 -         _add_isomers() ] <Atom name="O1" type="o" charge="-0.5453" epsilon="0.87864" sigma="0.295992190115" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name
periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C4" name2="C5" name3="C6" name4="C7" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H1ca" name2="C4" name3="C3" name4="C8" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H1ca" name2="C4" name3="C5" name4="H2ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H1ca" name2="C4" name3="C5" name4="C6" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C5" name2="C4" name3="C3" name4="C8" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C5" name2="C6" name3="C7" name4="H4ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C5" name2="C6" name3="C7" name4="C8" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H2ca" name2="C5" name3="C6" name4="H3ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H2ca" name2="C5" name3="C6" name4="C7" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C6" name2="C7" name3="C8" name4="C9" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H3ca" name2="C6" name3="C7" name4="H4ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H3ca" name2="C6" name3="C7" name4="C8" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C7" name2="C8" name3="C9" name4="H5ce" periodicity="2" phase="3.141592653589793" k="2.9288"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C7" name2="C8" name3="C9" name4="C10" periodicity="2" phase="3.141592653589793" k="2.9288"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H4ca" name2="C7" name3="C8" name4="C9" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C8" name2="C3" name3="C2" name4="C11" periodicity="2" phase="3.14159265359" k="4.184"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C8" name2="C9" name3="C10" name4="H6c2" periodicity="2" phase="3.14159265359" k="27.8236"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C8" name2="C9" name3="C10" name4="C11" periodicity="2" phase="3.14159265359" k="27.8236"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H5ce" name2="C9" name3="C10" name4="H6c2" periodicity="2" phase="3.14159265359" k="27.8236"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H5ce" name2="C9" name3="C10" name4="C11" periodicity="2" phase="3.14159265359" k="27.8236"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C11" name3="C2" name4="O1" periodicity="2" phase="3.141592653589793" k="43.932"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C2" name2="C4" name3="C3" name4="C8" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C5" name3="C4" name4="H1ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C4" name2="C6" name3="C5" name4="H2ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C5" name2="C7" name3="C6" name4="H3ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C6" name2="C8" name3="C7" name4="H4ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C7" name3="C8" name4="C9" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C8" name2="C10" name3="C9" name4="H5ce" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C9" name2="C11" name3="C10" name4="H6c2" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2258 -         _add_isomers() ] ISOMER: 1
# [ligands.py:2260 -         _add_isomers() ] <State index="1" log_population="1.0" g_k="0.0" proton_count="0">
#                 <Condition pH="7.8" log_population="1.0" temperature_kelvin="298.15"/>
#                 </State>
# [ligands.py:2287 -         _add_isomers() ] <Atom name="O1" type="oh" charge="-0.5008" epsilon="0.8803136" sigma="0.306647338784" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name="C2" type="ca" charge="0.1463" epsilon="0.359824" sigma="0.339966950842" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name="C3" type="ca" charge="-0.0496" epsilon="0.359824" sigma="0.339966950842" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name="C4" type="ca" charge="-0.0922" epsilon="0.359824" sigma="0.339966950842" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name="C5" type="ca" charge="-0.141" epsilon="0.359824" sigma="0.339966950842" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name="C6" type="ca" charge="-0.1145" epsilon="0.359824" sigma="0.339966950842" />
# [ligands.py:2287 -         _add_isomers() ] <Atom name
periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H5ca" name2="C9" name3="C10" name4="H6ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H5ca" name2="C9" name3="C10" name4="C11" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="H6ca" name2="C10" name3="C11" name4="H7ca" periodicity="2" phase="3.14159265359" k="15.167"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C11" name3="C2" name4="O1" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C2" name2="C8" name3="C3" name4="C4" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C5" name3="C4" name4="H1ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C4" name2="C6" name3="C5" name4="H2ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C5" name2="C7" name3="C6" name4="H3ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C6" name2="C8" name3="C7" name4="H4ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C3" name2="C7" name3="C8" name4="C9" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C8" name2="C10" name3="C9" name4="H5ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C9" name2="C11" name3="C10" name4="H6ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2389 -         _add_isomers() ] <Torsion name1="C2" name2="C10" name3="C11" name4="H7ca" periodicity="2" phase="3.141592653589793" k="4.6024"/>
# [ligands.py:2155 - _append_dummy_parameters() ] ################################
# [ligands.py:2156 - _append_dummy_parameters() ] Appending dummy parameters
# [ligands.py:2157 - _append_dummy_parameters() ] ################################
# [ligands.py:2162 - _append_dummy_parameters() ] Adding dummy atom element:
# <Type name="dH9oh" class="dH9oh" element="H" mass="1.008"/>
# [ligands.py:2162 - _append_dummy_parameters() ] Adding dummy atom element:
# <Type name="dH6ca" class="dH6ca" element="H" mass="1.008"/>
# [ligands.py:2162 - _append_dummy_parameters() ] Adding dummy atom element:
# <Type name="dH5ca" class="dH5ca" element="H" mass="1.008"/>
# [ligands.py:2162 - _append_dummy_parameters() ] Adding dummy atom element:
# <Type name="dH7ca" class="dH7ca" element="H" mass="1.008"/>
# [ligands.py:2166 - _append_dummy_parameters() ] Adding dummy atom nonbonded parameters:
# <Atom type="dH6ca" sigma="0" epsilon="0" charge="0.0"/>
# [ligands.py:2166 - _append_dummy_parameters() ] Adding dummy atom nonbonded parameters:
# <Atom type="dH5ca" sigma="0" epsilon="0" charge="0.0"/>
# [ligands.py:2166 - _append_dummy_parameters() ] Adding dummy atom nonbonded parameters:
# <Atom type="dH7ca" sigma="0" epsilon="0" charge="0.0"/>
# [ligands.py:2166 - _append_dummy_parameters() ] Adding dummy atom nonbonded parameters:
# <Atom type="dH9oh" sigma="0" epsilon="0" charge="0.0"/>
# [ligands.py:2172 - _append_dummy_parameters() ] <Bond type1="o" type2="dH9oh" length="0.0973" k="310787.52"/>
# [ligands.py:2172 - _append_dummy_parameters() ] <Bond type1="ce" type2="dH5ca" length="0.1086" k="289365.44"/>
# [ligands.py:2172 - _append_dummy_parameters() ] <Bond type1="c2" type2="dH6ca" length="0.1086" k="289365.44"/>
# [ligands.py:2172 - _append_dummy_parameters() ] <Bond type1="c3" type2="dH7ca" length="0.1086" k="289365.44"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="c3" type2="c2" type3="dH6ca" angle="2.09230070729" k="403.17024"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="ca" type2="ce" type3="dH5ca" angle="2.09230070729" k="403.17024"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="dH5ca" type2="ce" type3="c2" angle="2.09230070729" k="403.17024"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="hc" type2="c3" type3="dH7ca" angle="0.0" k="0.0"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="dH7ca" type2="c3" type3="c" angle="2.09230070729" k="403.17024"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="c2" type2="c3" type3="dH7ca" angle="2.09230070729" k="403.17024"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="c" type2="o" type3="dH9oh" angle="1.89507850182" k="410.032"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="ha" type2="ce" type3="dH5ca" angle="0.0" k="0.0"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="ha" type2="c2" type3="dH6ca" angle="0.0" k="0.0"/>
# [ligands.py:2178 - _append_dummy_parameters() ] <Angle type1="dH6ca" type2="c2" type3="ce" angle="2.09230070729" k="403.17024"/>
# [ligands.py:1632 - generate_protons_ffxml() ] Done!  Your result is located here: /home/mwieder/Work/Projects/protons-dev/protons/examples/tautomers/keto_enol/input//keto_enol.ffxml

# %%
simulation, driver, pdb_object = tautomer_utils.generate_simulation_and_driver(settings)
# Out:
# [driver.py:4434 - _add_xml_titration_groups() ] - Parameters for the different states as defined in ffxml
# [driver.py:4537 - _generating_parameter_for_current_state() ] ###############
# [driver.py:4539 - _generating_parameter_for_current_state() ] -- Looking at parameters of State: 0
# [driver.py:4561 - _generating_parameter_for_current_state() ] Parsing proper parameters from ffxml file
# [driver.py:3910 -         _cache_force() ] #########################
# [driver.py:3911 -         _cache_force() ] Titration group index 0
# [driver.py:3912 -         _cache_force() ] titration state index 0
# [driver.py:3913 -         _cache_force() ] #########################
# [driver.py:4537 - _generating_parameter_for_current_state() ] ###############
# [driver.py:4539 - _generating_parameter_for_current_state() ] -- Looking at parameters of State: 1
# [driver.py:4561 - _generating_parameter_for_current_state() ] Parsing proper parameters from ffxml file
# [driver.py:3910 -         _cache_force() ] #########################
# [driver.py:3911 -         _cache_force() ] Titration group index 0
# [driver.py:3912 -         _cache_force() ] titration state index 1
# [driver.py:3913 -         _cache_force() ] #########################

# %%
tautomer_utils.run_main(simulation, driver, pdb_object, settings)
# Out:
# NCMC attempts:   0%|          | 0/1000 [00:00<?, ?it/s][driver.py:3234 - _compute_log_probability() ] beta = 0.40090737504650614 mol/kJ, pressure = 1.0 atm, volume = 19.70461656669447 nm**3, multiple = -0.4820361653754678
# [driver.py:3241 - _compute_log_probability() ] g_k: 0.00
# [driver.py:3056 - _attempt_state_change() ] Calculate work for change from [0] to [1]
# [driver.py:3072 - _attempt_state_change() ] Acceptance probability: -26.589395
# [driver.py:3112 - _attempt_state_change() ] reject ncmc titration state change ...
# [calibration.py:133 -          adapt_zetas() ] Adaptation step     -199 : still in burn-in.
# NCMC attempts:   0%|          | 1/1000 [03:04<51:18:36, 184.90s/it]
# 0.0 0.0
# [driver.py:3234 - _compute_log_probability() ] beta = 0.40090737504650614 mol/kJ, pressure = 1.0 atm, volume = 19.466077589580166 nm**3, multiple = -0.47620076058940786
# [driver.py:3241 - _compute_log_probability() ] g_k: 0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e52dc71763f8> in <module>
# ----> 1 tautomer_utils.run_main(simulation, driver, pdb_object, settings)
#
# ~/Work/Projects/protons-dev/protons/examples/tautomers/tautomer_utils.py in run_main(simulation, driver, pdb_object, settings)
#      45                 simulation.update(1, pool="calibration")
#      46             else:
# ---> 47                 simulation.update(1)
#      48             simulation.adapt()
#      49         else:
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/protons-0.0.1a6+20.g79ce0da.dirty-py3.6.egg/protons/app/simulation.py in update(self, updates, move, pool)
#     116             The identifier for the pool of residues to update.
#     117         """
# --> 118         self._update(endUpdate=self.currentUpdate + updates, pool=pool, move=move)
#     119
#     120     def _update(self, pool=None, move=None, endUpdate=None, endTime=None):
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/protons-0.0.1a6+20.g79ce0da.dirty-py3.6.egg/protons/app/simulation.py in _update(self, pool, move, endUpdate, endTime)
#     142                 if endTime is not None and datetime.now() >= endTime:
#     143                     return
# --> 144             self.drive.update(move, residue_pool=pool, nattempts=updatesToGo)
#     145
#     146             self.currentUpdate += nextUpdates
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/protons-0.0.1a6+20.g79ce0da.dirty-py3.6.egg/protons/app/driver.py in update(self, proposal, residue_pool, nattempts)
#    1918             for attempt in range(nattempts):
#    1919                 self._attempt_number = attempt
# -> 1920                 self._attempt_state_change(proposal, residue_pool=residue_pool)
#    1921
#    1922             return
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/protons-0.0.1a6+20.g79ce0da.dirty-py3.6.egg/protons/app/driver.py in _attempt_state_change(self, proposal, residue_pool, reject_on_nan)
#    3045                             titration_group_indices,
#    3046                             initial_titration_states,
# -> 3047                             final_titration_states,
#    3048                         )
#    3049                 else:
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/protons-0.0.1a6+20.g79ce0da.dirty-py3.6.egg/protons/app/driver.py in _perform_ncmc_protocol(self, titration_group_indices, initial_titration_states, final_titration_states, salt_residue_indices, salt_states)
#    2848
#    2849             # propagation
# -> 2850             ncmc_integrator.step(self.propagations_per_step)
#    2851
#    2852             # logging of statistics
#
# ~/anaconda3/envs/protons-dev/lib/python3.6/site-packages/simtk/openmm/openmm.py in step(self, steps)
#   18561             the number of time steps to take
#   18562         """
# > 18563         return _openmm.CustomIntegrator_step(self, steps)
#   18564
#   18565
#
# KeyboardInterrupt:
